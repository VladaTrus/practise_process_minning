# %%
import pm4py

# %%
from pm4py.objects.log.importer.xes import factory as xes_importer
log = xes_importer.apply('RequestForPayment.xes')
# Out:
# /Users/vladlenatrus/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecatedWarning: apply is deprecated as of 1.3.0 and will be removed in 2.0.0. Use importer entrypoint instead

# %%
log[0]
# Out:
# {'attributes': {'Rfp_id': 'request for payment 148214', 'Project': 'project 148216', 'Task': 'UNKNOWN', 'concept:name': 'request for payment 148214', 'OrganizationalEntity': 'organizational unit 65463', 'Cost Type': 0, 'RequestedAmount': 34.33634285099345, 'Activity': 'UNKNOWN', 'RfpNumber': 'request for payment number 148215'}, 'events': [{'id': 'st_step 148220_0', 'org:resource': 'STAFF MEMBER', 'concept:name': 'Request For Payment SUBMITTED by EMPLOYEE', 'time:timestamp': datetime.datetime(2017, 1, 9, 9, 17, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'org:role': 'EMPLOYEE'}, '..', {'id': 'rp_request for payment 148214_16', 'org:resource': 'SYSTEM', 'concept:name': 'Payment Handled', 'time:timestamp': datetime.datetime(2017, 3, 16, 17, 31, 12, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'org:role': 'UNDEFINED'}]}

# %%
from pm4py.algo.discovery.dfg import factory as dfg_factory

dfg = dfg_factory.apply(log)
# Out:
# /Users/vladlenatrus/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecatedWarning: apply is deprecated as of 1.3.0 and will be removed in 2.0.0. Use algorithm entrypoint instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from pm4py.visualization.dfg import factory as dfg_vis_factory

gviz = dfg_vis_factory.apply(dfg, log=log, variant="frequency")
dfg_vis_factory.view(gviz)
# Out:
# /Users/vladlenatrus/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecatedWarning: apply is deprecated as of 1.3.0 and will be removed in 2.0.0. Use visualizer module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/vladlenatrus/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecatedWarning: view is deprecated as of 1.3.0 and will be removed in 2.0.0. Use visualizer module instead.
#   after removing the cwd from sys.path.

# %%
from pm4py.visualization.dfg import factory as dfg_vis_factory

gviz = dfg_vis_factory.apply(dfg, log=log, variant="performance")
dfg_vis_factory.view(gviz)
# Out:
# /Users/vladlenatrus/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecatedWarning: apply is deprecated as of 1.3.0 and will be removed in 2.0.0. Use visualizer module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/vladlenatrus/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecatedWarning: view is deprecated as of 1.3.0 and will be removed in 2.0.0. Use visualizer module instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Log skeleton

# %%
from pm4py.objects.log.importer.xes import importer as xes_importer
import os
log = xes_importer.apply(os.path.join('RequestForPayment.xes'))
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=6886, style=ProgressS…

# %%
from pm4py.algo.discovery.log_skeleton import algorithm as lsk_discovery
skeleton = lsk_discovery.apply(log, parameters={lsk_discovery.Variants.CLASSIC.value.Parameters.NOISE_THRESHOLD: 0.0})

# %%
skeleton['equivalence']
# Out:
# {('Request For Payment APPROVED by SUPERVISOR',
#   'Request For Payment FINAL_APPROVED by DIRECTOR'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER', 'Payment Handled'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#   'Request For Payment SUBMITTED by EMPLOYEE'),
#  ('Request For Payment FINAL_APPROVED by DIRECTOR',
#   'Request For Payment APPROVED by SUPERVISOR'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Payment Handled'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment APPROVED by BUDGET OWNER'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment REJECTED by EMPLOYEE'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Request Payment'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment REJECTED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment REJECTED by EMPLOYEE')}

# %% [markdown]
# ### Здесь строиттся дефолтный log skeleton

# %% [markdown]
# 1. Equivalence: contains the couples of activities that happen ALWAYS with the same frequency inside a trace.
# 2. Always-after: contains the couples of activities (A,B) such that an occurrence of A is ALWAYS followed, somewhen in the future of the trace, by an occurrence of B.
# 3. Always-before: contains the couples of activities (B,A) such that an occurrence of B is ALWAYS preceded, somewhen in the past of the trace, by an occurrence of A.
# 4. Never-together: contains the couples of activities (A,B) that NEVER happens together in the history of the trace.
# 5. Directly-follows: contains the list of directly-follows relations of the log.

# %%
skeleton
# Out:
# {'equivalence': {('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER', 'Payment Handled'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Payment Handled'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment APPROVED by BUDGET OWNER'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment REJECTED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Request Payment'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment REJECTED by ADMINISTRATION'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment REJECTED by EMPLOYEE')},
#  'always_after': {('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Payment Handled'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Payment Handled'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment APPROVED by BUDGET OWNER'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Request Payment'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment REJECTED by EMPLOYEE')},
#  'always_before': {('Payment Handled',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment REJECTED by ADMINISTRATION'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment REJECTED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment REJECTED by ADMINISTRATION'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment REJECTED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request Payment', 'Request For Payment SUBMITTED by EMPLOYEE')},
#  'never_together': {('Payment Handled',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Payment Handled', 'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment APPROVED by ADMINISTRATION',
#    'Request For Payment APPROVED by PRE_APPROVER'),
#   ('Request For Payment APPROVED by ADMINISTRATION',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment APPROVED by ADMINISTRATION',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment APPROVED by ADMINISTRATION',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment APPROVED by BUDGET OWNER',
#    'Request For Payment APPROVED by PRE_APPROVER'),
#   ('Request For Payment APPROVED by BUDGET OWNER',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment APPROVED by BUDGET OWNER',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment APPROVED by BUDGET OWNER',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment APPROVED by BUDGET OWNER',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment APPROVED by BUDGET OWNER',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment APPROVED by PRE_APPROVER',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment APPROVED by PRE_APPROVER',
#    'Request For Payment APPROVED by BUDGET OWNER'),
#   ('Request For Payment APPROVED by PRE_APPROVER',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment APPROVED by PRE_APPROVER',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment APPROVED by PRE_APPROVER',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment APPROVED by PRE_APPROVER',
#    'Request For Payment REJECTED by ADMINISTRATION'),
#   ('Request For Payment APPROVED by PRE_APPROVER',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment APPROVED by PRE_APPROVER',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment APPROVED by SUPERVISOR',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment APPROVED by BUDGET OWNER'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment APPROVED by PRE_APPROVER'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment REJECTED by ADMINISTRATION'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment REJECTED by EMPLOYEE'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment REJECTED by SUPERVISOR'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment FINAL_APPROVED by BUDGET OWNER', 'Request Payment'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment FINAL_APPROVED by DIRECTOR',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment APPROVED by PRE_APPROVER'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment REJECTED by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR', 'Payment Handled'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment APPROVED by BUDGET OWNER'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment APPROVED by PRE_APPROVER'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment REJECTED by SUPERVISOR'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment FOR_APPROVAL by SUPERVISOR', 'Request Payment'),
#   ('Request For Payment REJECTED by ADMINISTRATION',
#    'Request For Payment APPROVED by PRE_APPROVER'),
#   ('Request For Payment REJECTED by ADMINISTRATION',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by ADMINISTRATION',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment REJECTED by ADMINISTRATION',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment APPROVED by PRE_APPROVER'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment REJECTED by SUPERVISOR'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment REJECTED by EMPLOYEE',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment APPROVED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment REJECTED by ADMINISTRATION'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment REJECTED by SUPERVISOR'),
#   ('Request For Payment REJECTED by MISSING',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment APPROVED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment REJECTED by ADMINISTRATION'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment REJECTED by SUPERVISOR'),
#   ('Request For Payment REJECTED by PRE_APPROVER',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment REJECTED by SUPERVISOR',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by SUPERVISOR',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment REJECTED by SUPERVISOR',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment REJECTED by SUPERVISOR',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment REJECTED by SUPERVISOR',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment REJECTED by SUPERVISOR',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment REJECTED by SUPERVISOR',
#    'Request For Payment SAVED by EMPLOYEE'),
#   ('Request For Payment SAVED by EMPLOYEE', 'Payment Handled'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment APPROVED by ADMINISTRATION'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment APPROVED by BUDGET OWNER'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment APPROVED by PRE_APPROVER'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment APPROVED by SUPERVISOR'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment FINAL_APPROVED by DIRECTOR'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment FOR_APPROVAL by ADMINISTRATION'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment REJECTED by BUDGET OWNER'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment REJECTED by MISSING'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment REJECTED by PRE_APPROVER'),
#   ('Request For Payment SAVED by EMPLOYEE',
#    'Request For Payment REJECTED by SUPERVISOR'),
#   ('Request For Payment SAVED by EMPLOYEE', 'Request Payment'),
#   ('Request Payment', 'Request For Payment FINAL_APPROVED by BUDGET OWNER'),
#   ('Request Payment', 'Request For Payment FOR_APPROVAL by SUPERVISOR'),
#   ('Request Payment', 'Request For Payment SAVED by EMPLOYEE')},
#  'directly_follows': {('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#    'Payment Handled'),
#   ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#    'Request For Payment SUBMITTED by EMPLOYEE'),
#   ('Request For Payment REJECTED by BUDGET OWNER',
#    'Request For Payment REJECTED by EMPLOYEE')},
#  'activ_freq': {'Request For Payment SUBMITTED by EMPLOYEE': {0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    6},
#   'Request For Payment FINAL_APPROVED by SUPERVISOR': {0, 1, 2, 3},
#   'Request For Payment REJECTED by MISSING': {0, 1, 2},
#   'Request For Payment APPROVED by PRE_APPROVER': {0, 1, 2},
#   'Request Payment': {0, 1},
#   'Payment Handled': {0, 1},
#   'Request For Payment REJECTED by SUPERVISOR': {0, 1, 2},
#   'Request For Payment REJECTED by EMPLOYEE': {0, 1, 2, 3, 5},
#   'Request For Payment APPROVED by SUPERVISOR': {0, 1},
#   'Request For Payment FINAL_APPROVED by DIRECTOR': {0, 1},
#   'Request For Payment REJECTED by PRE_APPROVER': {0, 1, 2},
#   'Request For Payment SAVED by EMPLOYEE': {0, 1},
#   'Request For Payment REJECTED by ADMINISTRATION': {0, 1, 2, 3, 4, 5},
#   'Request For Payment APPROVED by ADMINISTRATION': {0, 1, 2, 3},
#   'Request For Payment APPROVED by BUDGET OWNER': {0, 1, 2, 3},
#   'Request For Payment REJECTED by BUDGET OWNER': {0, 1},
#   'Request For Payment FOR_APPROVAL by ADMINISTRATION': {0, 1},
#   'Request For Payment FINAL_APPROVED by BUDGET OWNER': {0, 1},
#   'Request For Payment FOR_APPROVAL by SUPERVISOR': {0, 1}}}

# %%
skeleton['equivalence']
# Out:
# {('Request For Payment APPROVED by SUPERVISOR',
#   'Request For Payment FINAL_APPROVED by DIRECTOR'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER', 'Payment Handled'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#   'Request For Payment SUBMITTED by EMPLOYEE'),
#  ('Request For Payment FINAL_APPROVED by DIRECTOR',
#   'Request For Payment APPROVED by SUPERVISOR'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Payment Handled'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment APPROVED by BUDGET OWNER'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment REJECTED by EMPLOYEE'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Request Payment'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment REJECTED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment REJECTED by EMPLOYEE')}

# %%
from pm4py.objects.log.importer.xes import importer as xes_importer
import os
log = xes_importer.apply(os.path.join('RequestForPayment.xes'))
from copy import deepcopy
from pm4py.algo.filtering.log.variants import variants_filter
filtered_log = variants_filter.apply_auto_filter(deepcopy(log))
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=6886, style=ProgressS…

# %%
filtered_log
# Out:
# [{'attributes': {'Rfp_id': 'request for payment 159193', 'Project': 'project 147620', 'Task': 'task 76059', 'concept:name': 'request for payment 159193', 'OrganizationalEntity': 'organizational unit 65463', 'Cost Type': 0, 'RequestedAmount': 91.01847341754711, 'Activity': 'activity 505', 'RfpNumber': 'request for payment number 159194'}, 'events': [{'id': 'st_step 159196_0', 'org:resource': 'STAFF MEMBER', 'concept:name': 'Request For Payment SUBMITTED by EMPLOYEE', 'time:timestamp': datetime.datetime(2018, 1, 7, 22, 42, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'org:role': 'EMPLOYEE'}, '..', {'id': 'rp_request for payment 159193_16', 'org:resource': 'SYSTEM', 'concept:name': 'Payment Handled', 'time:timestamp': datetime.datetime(2018, 1, 15, 17, 31, 33, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'org:role': 'UNDEFINED'}]}, '....', {'attributes': {'Rfp_id': 'request for payment 185000', 'Project': 'project 147860', 'Task': 'task 152704', 'concept:name': 'request for payment 185000', 'OrganizationalEntity': 'organizational unit 65468', 'Cost Type': 0, 'RequestedAmount': 15.409660246909189, 'Activity': 'activity 505', 'RfpNumber': 'request for payment number 185001'}, 'events': [{'id': 'st_step 185002_0', 'org:resource': 'STAFF MEMBER', 'concept:name': 'Request For Payment SUBMITTED by EMPLOYEE', 'time:timestamp': datetime.datetime(2018, 12, 29, 12, 34, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'org:role': 'EMPLOYEE'}, '..', {'id': 'rp_request for payment 185000_16', 'org:resource': 'SYSTEM', 'concept:name': 'Payment Handled', 'time:timestamp': datetime.datetime(2019, 1, 10, 17, 31, 9, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'org:role': 'UNDEFINED'}]}]

# %%
from pm4py.algo.conformance.log_skeleton import algorithm as lsk_conformance
conf_result = lsk_conformance.apply(filtered_log, skeleton)

# %%
len(conf_result)
# Out:
# 4773

# %%
conf_result
# Out:
# [{'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
# ...
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 21,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  ...]

# %%
from pm4py.algo.conformance.log_skeleton import algorithm as lsk_conformance
conf_result = lsk_conformance.apply(log, skeleton)

# %%
conf_result
# Out:
# [{'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 37,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 26,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 37,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 37,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 32,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 42,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 19,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 42,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 42,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 32,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 32,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 42,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 42,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 37,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 23,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 19,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 26,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 7,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 26,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 19,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 19,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 37,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 19,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 26,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 19,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 20,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 37,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 28,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
# ...
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 11,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 19,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 7,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 19,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 39,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 15,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 7,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 7,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 16,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 25,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  ...]

# %% [markdown]
# ### Добавим 2%, 3%, 5% и 10% шум.

# %%
from pm4py.algo.discovery.log_skeleton import algorithm as lsk_discovery
skeleton_2 = lsk_discovery.apply(log, parameters={lsk_discovery.Variants.CLASSIC.value.Parameters.NOISE_THRESHOLD: 0.02})

from pm4py.algo.conformance.log_skeleton import algorithm as lsk_conformance
conf_result = lsk_conformance.apply(log, skeleton_2)

# %%
skeleton['equivalence']
# Out:
# {('Request For Payment APPROVED by SUPERVISOR',
#   'Request For Payment FINAL_APPROVED by DIRECTOR'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER', 'Payment Handled'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#   'Request For Payment SUBMITTED by EMPLOYEE'),
#  ('Request For Payment FINAL_APPROVED by DIRECTOR',
#   'Request For Payment APPROVED by SUPERVISOR'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Payment Handled'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment APPROVED by BUDGET OWNER'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment REJECTED by EMPLOYEE'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Request Payment'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment REJECTED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment REJECTED by EMPLOYEE')}

# %%
skeleton_2['equivalence']
# Out:
# {('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#  ('Payment Handled', 'Request Payment'),
#  ('Request For Payment APPROVED by SUPERVISOR',
#   'Request For Payment FINAL_APPROVED by DIRECTOR'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER', 'Payment Handled'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FINAL_APPROVED by BUDGET OWNER',
#   'Request For Payment SUBMITTED by EMPLOYEE'),
#  ('Request For Payment FINAL_APPROVED by DIRECTOR',
#   'Request For Payment APPROVED by SUPERVISOR'),
#  ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#  ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Payment Handled'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment APPROVED by BUDGET OWNER'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION',
#   'Request For Payment REJECTED by EMPLOYEE'),
#  ('Request For Payment FOR_APPROVAL by ADMINISTRATION', 'Request Payment'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment APPROVED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment REJECTED by ADMINISTRATION'),
#  ('Request For Payment FOR_APPROVAL by SUPERVISOR',
#   'Request For Payment REJECTED by EMPLOYEE'),
#  ('Request Payment', 'Payment Handled'),
#  ('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR')}

# %%
conf_result[0]
# Out:
# {'deviations': [('activ_freq',
#    ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#   ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#   ('equivalence',
#    (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#     ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#   ('never_together',
#    (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#     ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#     ('Request For Payment SUBMITTED by EMPLOYEE',
#      'Request For Payment REJECTED by MISSING'),
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#      'Request For Payment REJECTED by MISSING')))],
#  'no_dev_total': 10,
#  'no_constr_total': 85,
#  'dev_fitness': 0.8823529411764706,
#  'is_fit': False}

# %%
from pm4py.algo.discovery.log_skeleton import algorithm as lsk_discovery
skeleton_3 = lsk_discovery.apply(log, parameters={lsk_discovery.Variants.CLASSIC.value.Parameters.NOISE_THRESHOLD: 0.03})

from pm4py.algo.conformance.log_skeleton import algorithm as lsk_conformance
conf_result = lsk_conformance.apply(log, skeleton_3)

# %%
conf_result
# Out:
# [{'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 10,
#   'no_constr_total': 88,
#   'dev_fitness': 0.8863636363636364,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR')))],
#   'no_dev_total': 5,
#   'no_constr_total': 80,
#   'dev_fitness': 0.9375,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 10,
#   'no_constr_total': 88,
#   'dev_fitness': 0.8863636363636364,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 10,
#   'no_constr_total': 88,
#   'dev_fitness': 0.8863636363636364,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('always_before',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Payment Handled', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Request Payment', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 12,
#   'no_constr_total': 81,
#   'dev_fitness': 0.8518518518518519,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 10,
#   'no_constr_total': 73,
#   'dev_fitness': 0.863013698630137,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 12,
#   'no_constr_total': 75,
#   'dev_fitness': 0.84,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 40,
#   'dev_fitness': 0.8,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 12,
#   'no_constr_total': 75,
#   'dev_fitness': 0.84,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 12,
#   'no_constr_total': 75,
#   'dev_fitness': 0.84,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 96,
#   'dev_fitness': 0.9479166666666666,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 30,
#   'dev_fitness': 0.9333333333333333,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 31,
#   'dev_fitness': 0.935483870967742,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 55,
#   'dev_fitness': 0.8545454545454545,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 55,
#   'dev_fitness': 0.8545454545454545,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 30,
#   'dev_fitness': 0.9333333333333333,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 96,
#   'dev_fitness': 0.9479166666666666,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('always_before',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Payment Handled', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Request Payment', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 12,
#   'no_constr_total': 81,
#   'dev_fitness': 0.8518518518518519,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('always_before',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Payment Handled', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Request Payment', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 12,
#   'no_constr_total': 81,
#   'dev_fitness': 0.8518518518518519,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 55,
#   'dev_fitness': 0.8545454545454545,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 12,
#   'no_constr_total': 75,
#   'dev_fitness': 0.84,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by EMPLOYEE', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 2)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 3,
#   'no_constr_total': 31,
#   'dev_fitness': 0.9032258064516129,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 12,
#   'no_constr_total': 75,
#   'dev_fitness': 0.84,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 96,
#   'dev_fitness': 0.9479166666666666,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 2)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 11,
#   'no_constr_total': 88,
#   'dev_fitness': 0.875,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 30,
#   'dev_fitness': 0.9333333333333333,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 31,
#   'dev_fitness': 0.935483870967742,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('always_after',
#     (('Request For Payment APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by DIRECTOR', 'Payment Handled'),
#      ('Request For Payment APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by DIRECTOR', 'Request Payment'))),
#    ('equivalence',
#     (('Request For Payment APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by DIRECTOR', 'Payment Handled'),
#      ('Request For Payment APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by DIRECTOR', 'Request Payment'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 12,
#   'no_constr_total': 48,
#   'dev_fitness': 0.75,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 96,
#   'dev_fitness': 0.9479166666666666,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 40,
#   'dev_fitness': 0.8,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by EMPLOYEE', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 3)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR')))],
#   'no_dev_total': 7,
#   'no_constr_total': 80,
#   'dev_fitness': 0.9125,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 31,
#   'dev_fitness': 0.935483870967742,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 31,
#   'dev_fitness': 0.935483870967742,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 31,
#   'dev_fitness': 0.935483870967742,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 96,
#   'dev_fitness': 0.9479166666666666,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 31,
#   'dev_fitness': 0.935483870967742,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Request For Payment SAVED by EMPLOYEE', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', {1, 2}))],
#   'no_dev_total': 2,
#   'no_constr_total': 20,
#   'dev_fitness': 0.9,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 55,
#   'dev_fitness': 0.8545454545454545,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Request For Payment SAVED by EMPLOYEE', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', {1, 2}))],
#   'no_dev_total': 2,
#   'no_constr_total': 20,
#   'dev_fitness': 0.9,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Request For Payment SAVED by EMPLOYEE', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', {1, 2}))],
#   'no_dev_total': 2,
#   'no_constr_total': 20,
#   'dev_fitness': 0.9,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 31,
#   'dev_fitness': 0.935483870967742,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
# ...
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 96,
#   'dev_fitness': 0.9479166666666666,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Payment Handled')))],
#   'no_dev_total': 5,
#   'no_constr_total': 28,
#   'dev_fitness': 0.8214285714285714,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 40,
#   'dev_fitness': 0.8,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 96,
#   'dev_fitness': 0.9479166666666666,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 31,
#   'dev_fitness': 0.935483870967742,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Request For Payment SAVED by EMPLOYEE', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', {1, 2}))],
#   'no_dev_total': 2,
#   'no_constr_total': 20,
#   'dev_fitness': 0.9,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Payment Handled')))],
#   'no_dev_total': 5,
#   'no_constr_total': 28,
#   'dev_fitness': 0.8214285714285714,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Payment Handled')))],
#   'no_dev_total': 5,
#   'no_constr_total': 28,
#   'dev_fitness': 0.8214285714285714,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 76,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  ...]

# %% [markdown]
# ### Здесь уже видно, что добавив шум, некоторые пути начинают классфицироваться как некорректные.

# %%
conf_result[0]
# Out:
# {'deviations': [('activ_freq',
#    ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#   ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#   ('equivalence',
#    (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#     ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#   ('never_together',
#    (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#     ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#     ('Request For Payment SUBMITTED by EMPLOYEE',
#      'Request For Payment REJECTED by MISSING'),
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#      'Request For Payment REJECTED by MISSING')))],
#  'no_dev_total': 10,
#  'no_constr_total': 88,
#  'dev_fitness': 0.8863636363636364,
#  'is_fit': False}

# %%
from pm4py.algo.discovery.log_skeleton import algorithm as lsk_discovery
skeleton_5 = lsk_discovery.apply(log, parameters={lsk_discovery.Variants.CLASSIC.value.Parameters.NOISE_THRESHOLD: 0.05})

from pm4py.algo.conformance.log_skeleton import algorithm as lsk_conformance
conf_result = lsk_conformance.apply(log, skeleton_5)

# %%
conf_result
# Out:
# [{'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 11,
#   'no_constr_total': 91,
#   'dev_fitness': 0.8791208791208791,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR')))],
#   'no_dev_total': 5,
#   'no_constr_total': 84,
#   'dev_fitness': 0.9404761904761905,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 11,
#   'no_constr_total': 91,
#   'dev_fitness': 0.8791208791208791,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 11,
#   'no_constr_total': 91,
#   'dev_fitness': 0.8791208791208791,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('always_before',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Payment Handled', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Request Payment', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 12,
#   'no_constr_total': 82,
#   'dev_fitness': 0.8536585365853658,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 10,
#   'no_constr_total': 75,
#   'dev_fitness': 0.8666666666666667,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 14,
#   'no_constr_total': 85,
#   'dev_fitness': 0.8352941176470589,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 42,
#   'dev_fitness': 0.8095238095238095,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 14,
#   'no_constr_total': 85,
#   'dev_fitness': 0.8352941176470589,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 14,
#   'no_constr_total': 85,
#   'dev_fitness': 0.8352941176470589,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 7,
#   'no_constr_total': 104,
#   'dev_fitness': 0.9326923076923077,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 34,
#   'dev_fitness': 0.9411764705882353,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 3,
#   'no_constr_total': 38,
#   'dev_fitness': 0.9210526315789473,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 58,
#   'dev_fitness': 0.8620689655172413,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 58,
#   'dev_fitness': 0.8620689655172413,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 34,
#   'dev_fitness': 0.9411764705882353,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 7,
#   'no_constr_total': 104,
#   'dev_fitness': 0.9326923076923077,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('always_before',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Payment Handled', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Request Payment', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 12,
#   'no_constr_total': 82,
#   'dev_fitness': 0.8536585365853658,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('always_before',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Payment Handled', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Request Payment', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 12,
#   'no_constr_total': 82,
#   'dev_fitness': 0.8536585365853658,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 58,
#   'dev_fitness': 0.8620689655172413,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 14,
#   'no_constr_total': 85,
#   'dev_fitness': 0.8352941176470589,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by EMPLOYEE', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 2)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 4,
#   'no_constr_total': 38,
#   'dev_fitness': 0.8947368421052632,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 14,
#   'no_constr_total': 85,
#   'dev_fitness': 0.8352941176470589,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 7,
#   'no_constr_total': 104,
#   'dev_fitness': 0.9326923076923077,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 2)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 11,
#   'no_constr_total': 91,
#   'dev_fitness': 0.8791208791208791,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),))],
#   'no_dev_total': 2,
#   'no_constr_total': 34,
#   'dev_fitness': 0.9411764705882353,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 3,
#   'no_constr_total': 38,
#   'dev_fitness': 0.9210526315789473,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('always_after',
#     (('Request For Payment APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by DIRECTOR', 'Payment Handled'),
#      ('Request For Payment APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by DIRECTOR', 'Request Payment'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by DIRECTOR', 'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment APPROVED by SUPERVISOR', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by DIRECTOR', 'Payment Handled'),
#      ('Request For Payment APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by DIRECTOR', 'Request Payment'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 13,
#   'no_constr_total': 49,
#   'dev_fitness': 0.7346938775510203,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 7,
#   'no_constr_total': 104,
#   'dev_fitness': 0.9326923076923077,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 42,
#   'dev_fitness': 0.8095238095238095,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by EMPLOYEE', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 3)),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR')))],
#   'no_dev_total': 7,
#   'no_constr_total': 84,
#   'dev_fitness': 0.9166666666666666,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 3,
#   'no_constr_total': 38,
#   'dev_fitness': 0.9210526315789473,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 3,
#   'no_constr_total': 38,
#   'dev_fitness': 0.9210526315789473,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 3,
#   'no_constr_total': 38,
#   'dev_fitness': 0.9210526315789473,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 7,
#   'no_constr_total': 104,
#   'dev_fitness': 0.9326923076923077,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 3,
#   'no_constr_total': 38,
#   'dev_fitness': 0.9210526315789473,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Request For Payment SAVED by EMPLOYEE', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', {1, 2}))],
#   'no_dev_total': 2,
#   'no_constr_total': 20,
#   'dev_fitness': 0.9,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 58,
#   'dev_fitness': 0.8620689655172413,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Request For Payment SAVED by EMPLOYEE', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', {1, 2}))],
#   'no_dev_total': 2,
#   'no_constr_total': 20,
#   'dev_fitness': 0.9,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
# ...
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 7,
#   'no_constr_total': 104,
#   'dev_fitness': 0.9326923076923077,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Payment Handled')))],
#   'no_dev_total': 5,
#   'no_constr_total': 28,
#   'dev_fitness': 0.8214285714285714,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by MISSING', 1)),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 8,
#   'no_constr_total': 42,
#   'dev_fitness': 0.8095238095238095,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 7,
#   'no_constr_total': 104,
#   'dev_fitness': 0.9326923076923077,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 3,
#   'no_constr_total': 38,
#   'dev_fitness': 0.9210526315789473,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Request For Payment SAVED by EMPLOYEE', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', {1, 2}))],
#   'no_dev_total': 2,
#   'no_constr_total': 20,
#   'dev_fitness': 0.9,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Payment Handled')))],
#   'no_dev_total': 5,
#   'no_constr_total': 28,
#   'dev_fitness': 0.8214285714285714,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Payment Handled')))],
#   'no_dev_total': 5,
#   'no_constr_total': 28,
#   'dev_fitness': 0.8214285714285714,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 61,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 77,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  ...]

# %%
from pm4py.algo.discovery.log_skeleton import algorithm as lsk_discovery
skeleton_10 = lsk_discovery.apply(log, parameters={lsk_discovery.Variants.CLASSIC.value.Parameters.NOISE_THRESHOLD: 0.1})

from pm4py.algo.conformance.log_skeleton import algorithm as lsk_conformance
conf_result = lsk_conformance.apply(log, skeleton_10)

# %%
conf_result
# Out:
# [{'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 20,
#   'no_constr_total': 109,
#   'dev_fitness': 0.8165137614678899,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment SUBMITTED by EMPLOYEE'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment REJECTED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment REJECTED by SUPERVISOR')))],
#   'no_dev_total': 12,
#   'no_constr_total': 101,
#   'dev_fitness': 0.8811881188118812,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 20,
#   'no_constr_total': 109,
#   'dev_fitness': 0.8165137614678899,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 20,
#   'no_constr_total': 109,
#   'dev_fitness': 0.8165137614678899,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by DIRECTOR', 1)),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', {1})),
#    ('always_before',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('equivalence',
#     (('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'))),
#    ('never_together',
#     (('Payment Handled', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by DIRECTOR'),
#      ('Request Payment', 'Request For Payment APPROVED by SUPERVISOR'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment FINAL_APPROVED by DIRECTOR')))],
#   'no_dev_total': 13,
#   'no_constr_total': 98,
#   'dev_fitness': 0.8673469387755102,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment FINAL_APPROVED by SUPERVISOR', 2)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Payment Handled', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request Payment', 'Request For Payment FINAL_APPROVED by SUPERVISOR'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request Payment', 'Request For Payment REJECTED by MISSING'),
#      ('Payment Handled', 'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 13,
#   'no_constr_total': 88,
#   'dev_fitness': 0.8522727272727273,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('always_after',
#     (('Request For Payment APPROVED by PRE_APPROVER', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment APPROVED by PRE_APPROVER', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 27,
#   'no_constr_total': 98,
#   'dev_fitness': 0.7244897959183674,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING')))],
#   'no_dev_total': 10,
#   'no_constr_total': 49,
#   'dev_fitness': 0.7959183673469388,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('always_after',
#     (('Request For Payment APPROVED by PRE_APPROVER', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment APPROVED by PRE_APPROVER', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 27,
#   'no_constr_total': 98,
#   'dev_fitness': 0.7244897959183674,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('always_after',
#     (('Request For Payment APPROVED by PRE_APPROVER', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment APPROVED by PRE_APPROVER', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 27,
#   'no_constr_total': 98,
#   'dev_fitness': 0.7244897959183674,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment SUBMITTED by EMPLOYEE'))),
#    ('never_together',
#     (('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 21,
#   'no_constr_total': 123,
#   'dev_fitness': 0.8292682926829268,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', {1})),
#    ('activ_freq', ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),))],
#   'no_dev_total': 5,
#   'no_constr_total': 42,
#   'dev_fitness': 0.8809523809523809,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', {1})),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 6,
#   'no_constr_total': 43,
#   'dev_fitness': 0.8604651162790697,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('always_after',
#     (('Request For Payment APPROVED by PRE_APPROVER', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment APPROVED by PRE_APPROVER', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 16,
#   'no_constr_total': 70,
#   'dev_fitness': 0.7714285714285715,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by MISSING', 1)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('always_after',
#     (('Request For Payment APPROVED by PRE_APPROVER', 'Payment Handled'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment APPROVED by PRE_APPROVER', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by MISSING'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 16,
#   'no_constr_total': 70,
#   'dev_fitness': 0.7714285714285715,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', {1})),
#    ('activ_freq', ('Request For Payment REJECTED by SUPERVISOR', 1)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by SUPERVISOR'),))],
#   'no_dev_total': 5,
#   'no_constr_total': 42,
#   'dev_fitness': 0.8809523809523809,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', 2)),
#    ('equivalence',
#     (('Payment Handled', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment SUBMITTED by EMPLOYEE'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment SUBMITTED by EMPLOYEE'))),
#    ('never_together',
#     (('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request For Payment APPROVED by PRE_APPROVER',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment REJECTED by EMPLOYEE'),
#      ('Request Payment', 'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 21,
#   'no_constr_total': 123,
#   'dev_fitness': 0.8292682926829268,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
# ...
#   'no_dev_total': 21,
#   'no_constr_total': 123,
#   'dev_fitness': 0.8292682926829268,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', {1})),
#    ('activ_freq', ('Request For Payment REJECTED by PRE_APPROVER', 1)),
#    ('activ_freq', ('Request Payment', {1})),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER'),
#      ('Request For Payment REJECTED by EMPLOYEE',
#       'Request For Payment REJECTED by PRE_APPROVER')))],
#   'no_dev_total': 6,
#   'no_constr_total': 43,
#   'dev_fitness': 0.8604651162790697,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request For Payment FINAL_APPROVED by SUPERVISOR', {1})),
#    ('activ_freq', ('Request For Payment SAVED by EMPLOYEE', 1)),
#    ('activ_freq', ('Request For Payment SUBMITTED by EMPLOYEE', {1})),
#    ('activ_freq', ('Request Payment', {1}))],
#   'no_dev_total': 5,
#   'no_constr_total': 23,
#   'dev_fitness': 0.782608695652174,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request Payment', {1})),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Payment Handled')))],
#   'no_dev_total': 7,
#   'no_constr_total': 35,
#   'dev_fitness': 0.8,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq', ('Payment Handled', {1})),
#    ('activ_freq', ('Request Payment', {1})),
#    ('always_after',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Payment Handled'))),
#    ('directly_follows',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request Payment'),)),
#    ('equivalence',
#     (('Request For Payment FINAL_APPROVED by SUPERVISOR', 'Request Payment'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Payment Handled')))],
#   'no_dev_total': 7,
#   'no_constr_total': 35,
#   'dev_fitness': 0.8,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [],
#   'no_dev_total': 0,
#   'no_constr_total': 74,
#   'dev_fitness': 1.0,
#   'is_fit': True},
#  {'deviations': [('activ_freq',
#     ('Request For Payment APPROVED by PRE_APPROVER', 1)),
#    ('never_together',
#     (('Request For Payment SUBMITTED by EMPLOYEE',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Payment Handled', 'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request For Payment FINAL_APPROVED by SUPERVISOR',
#       'Request For Payment APPROVED by PRE_APPROVER'),
#      ('Request Payment', 'Request For Payment APPROVED by PRE_APPROVER')))],
#   'no_dev_total': 5,
#   'no_constr_total': 95,
#   'dev_fitness': 0.9473684210526316,
#   'is_fit': False},
#  ...]

# %% [markdown]
# ### Alpha-miner

# %%
import os
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.algo.discovery.alpha import algorithm as alpha_miner

log = xes_importer.apply(os.path.join('RequestForPayment.xes'))
net, im, fm = alpha_miner.apply(log)
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=6886, style=ProgressS…

# %%
from pm4py.evaluation.replay_fitness import evaluator as replay_fitness_evaluator
fitness = replay_fitness_evaluator.apply(log, net, im, fm, variant=replay_fitness_evaluator.Variants.TOKEN_BASED)

# %%
fitness
# Out:
# {'perc_fit_traces': 0.0,
#  'average_trace_fitness': 0.7075559456402116,
#  'log_fitness': 0.7115349030516815}

# %%
# from pm4py.evaluation.replay_fitness import evaluator as replay_fitness_evaluator
# fitness = replay_fitness_evaluator.apply(log, net, im, fm, variant=replay_fitness_evaluator.Variants.ALIGNMENT_BASED)

# %% [markdown]
# trying to apply alignments on a Petri net that is not a relaxed sound net!!

# %%
from pm4py.evaluation.precision import evaluator as precision_evaluator
prec = precision_evaluator.apply(log, net, im, fm, variant=precision_evaluator.Variants.ETCONFORMANCE_TOKEN)

# %%
prec
# Out:
# 0.0

# %%
# from pm4py.evaluation.precision import evaluator as precision_evaluator
# prec = precision_evaluator.apply(log, net, im, fm, variant=precision_evaluator.Variants.ALIGN_ETCONFORMANCE)

# %% [markdown]
# trying to apply Align-ETConformance on a Petri net that is not a relaxed sound net!!

# %% [markdown]
# ### IMDFs

# %%
import os
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.algo.discovery.inductive import algorithm as inductive_miner

log = xes_importer.apply(os.path.join('RequestForPayment.xes'))
net, initial_marking, final_marking = inductive_miner.apply(log)
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=6886, style=ProgressS…

# %%
from pm4py.evaluation.replay_fitness import evaluator as replay_fitness_evaluator
fitness = replay_fitness_evaluator.apply(log, net, im, fm, variant=replay_fitness_evaluator.Variants.TOKEN_BASED)

# %%
fitness
# Out:
# {'perc_fit_traces': 0.0,
#  'average_trace_fitness': 0.5780384200157019,
#  'log_fitness': 0.618808191810792}

# %%
from pm4py.evaluation.precision import evaluator as precision_evaluator
prec = precision_evaluator.apply(log, net, im, fm, variant=precision_evaluator.Variants.ETCONFORMANCE_TOKEN)

# %%
prec
# Out:
# 1.0

# %% [markdown]
# ### Heuristic Miner

# %%
from pm4py.objects.log.importer.xes import importer as xes_importer
import os
log_path = os.path.join('RequestForPayment.xes')
log = xes_importer.apply(log_path)

from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
heu_net = heuristics_miner.apply_heu(log, parameters={heuristics_miner.Variants.CLASSIC.value.Parameters.DEPENDENCY_THRESH: 0.99})
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=6886, style=ProgressS…

# %%
from pm4py.visualization.heuristics_net import visualizer as hn_visualizer
gviz = hn_visualizer.apply(heu_net)
hn_visualizer.view(gviz)
# Out:
# Warning: # is not a known color.

# %%
from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
net, im, fm = heuristics_miner.apply(log, parameters={heuristics_miner.Variants.CLASSIC.value.Parameters.DEPENDENCY_THRESH: 0.99})

from pm4py.visualization.petrinet import visualizer as pn_visualizer
gviz = pn_visualizer.apply(net, im, fm)
pn_visualizer.view(gviz)

# %%
from pm4py.evaluation.replay_fitness import evaluator as replay_fitness_evaluator
fitness = replay_fitness_evaluator.apply(log, net, im, fm, variant=replay_fitness_evaluator.Variants.TOKEN_BASED)

# %%
fitness
# Out:
# {'perc_fit_traces': 38.28056927098461,
#  'average_trace_fitness': 0.933352662861754,
#  'log_fitness': 0.9466077095037391}

# %%
from pm4py.evaluation.precision import evaluator as precision_evaluator
prec = precision_evaluator.apply(log, net, im, fm, variant=precision_evaluator.Variants.ETCONFORMANCE_TOKEN)

# %%
prec
# Out:
# 0.8489028761255355

# %% [markdown]
# ### Business Hours

# %%
from pm4py.util.business_hours import BusinessHours
from datetime import datetime

st = datetime.fromtimestamp(100000000)
et = datetime.fromtimestamp(200000000)
bh_object = BusinessHours(st, et)
worked_time = bh_object.getseconds()
print(worked_time)
# Out:
# 29736000

# %%
bh_object = BusinessHours(st, et, worktiming=[10, 16], weekends=[5, 6, 7])
worked_time = bh_object.getseconds()
print(worked_time)
# Out:
# 14277600
